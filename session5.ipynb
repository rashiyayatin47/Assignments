# %% [markdown]
# #Task 1

# %%
# Create a list called playlist_ids with 5 integers representing Spotify playlist IDs, then use append() to 
# add a new playlist ID at the end and print the updated list.

playlist_ids=[1,2,3,4,5]
playlist_ids.append(6)
print(playlist_ids)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# #Task 2

# %%
# Simulate a Flipkart shopping cart: start with a list cart_items containing 't-shirt', 'shoes'. Use extend() 
# to add ['jeans', 'cap'] to the cart, then print the final list of items.

cart_items = ['t-shirt', 'shoes']

cart_items.extend(['jeans', 'cap'])

print(cart_items)
# Out:
# ['t-shirt', 'shoes', 'jeans', 'cap']

# %% [markdown]
# #Task 3

# %%
# Write a function remove_last_item(order_list) that pops the last item from a Zomato order list and 
# returns the removed item. Test it with a sample order_list.

order_list=['pizza','burger','coca-cola','pepsi']
order_list.pop(-1)

print(order_list)
# Out:
# ['pizza', 'burger', 'coca-cola']

# %% [markdown]
# #Task 4

# %%
#Create a tuple called insta_filters with 4 Instagram filter names. Try to update the second filter and observe what
#  error you get. Explain in a comment why this happens.<br><br><em><strong>Hint:</strong> Tuples are immutable, so direct assignment
#  won't work.</em>

insta_filters = ("Clarendon", "Juno", "Lark", "Valencia")

#insta_filters[1]='falaaana'

# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #Task 5

# %%
# Given two scenarios — storing a user's favorite genres (which may change) and storing a fixed set of IRCTC train
#  classes ('Sleeper', 'AC 3 Tier', 'AC 2 Tier') — choose whether to use a list or tuple for each. Write one sentence explaining 
# your choice for both.

train_classes = ("Sleeper", "AC 3 Tier", "AC 2 Tier")

# Tuple for train classes because they are fixed and should not be changed.

favorite_genres = ["thriller", "Horror", "Action"]

# List for favorite genres because the user can add or remove genres.
